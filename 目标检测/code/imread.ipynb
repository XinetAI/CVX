# %%
import numpy as np
import cv2
np.set_printoptions(2)

# %pylab inline

img_name = '../images/catdog.jpg'
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
def cv2ndarray(img_name):
    img_cv = cv2.imread(img_name)
    img = cv2.cvtColor(img_cv, cv2.COLOR_BGR2RGB)
    plt.imshow(img)
    plt.show()


def plt2ndarray(img_name):
    img = plt.imread(img_name)
    plt.imshow(img)
    plt.show()

# %%
# %%timeit
cv2ndarray(img_name)
# Out:
# 179 ms ± 22.9 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %%timeit
plt2ndarray(img_name)
# Out:
# 174 ms ± 11.6 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
